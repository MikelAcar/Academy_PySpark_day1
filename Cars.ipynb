# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
dfbackup = pd.read_csv("cars_dataset.csv")
df = pd.read_csv("cars_dataset.csv")
# Out:
# C:\Users\mikel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#       src_ad_id  telclicks  bids  kleur            carrosserie   kmstand  \
# 0  1.007678e+09        0.0   0.0    Wit           Terreinwagen   90800.0
# 1  1.109203e+09        0.0  20.0  Zwart                      ?  335000.0
# 2  1.038535e+09        0.0   6.0    Wit  Hatchback (3/5-deurs)   53619.0
# 3  1.081274e+09        0.0  14.0  Zwart  Hatchback (3/5-deurs)  175000.0
# 4  1.176745e+09        0.0  12.0  Blauw  Hatchback (3/5-deurs)  150000.0
#
#    days_live  photo_cnt aantaldeuren  n_asq     ...      energielabel  \
# 0        100          8            5    282     ...                 B
# 1         14          8         None    147     ...                 A
# 2         27         14            3    130     ...                 A
# 3          3         11            3    125     ...                 C
# 4          3          5            5    114     ...                 B
#
#         brand   l2 ad_start_dt vermogen webclicks  model  aantalstoelen  \
# ...

# %%
df.isna().sum()
# Out:
# src_ad_id             0
# telclicks             9
# bids                  9
# kleur                 0
# carrosserie           0
# kmstand            1404
# days_live             0
# photo_cnt             0
# aantaldeuren          0
# n_asq                 0
# bouwjaar              0
# emissie               0
# energielabel          0
# brand                 0
# l2                    0
# ad_start_dt           0
# vermogen              0
# webclicks             9
# model                 1
# aantalstoelen         1
# price                 7
# test group       179428
# dtype: int64

# %%
df.describe()
# Out:
#           src_ad_id      telclicks           bids       kmstand  \
# count  1.830620e+05  183053.000000  183053.000000  1.816580e+05
# mean   1.108543e+09       0.916882       0.678175  1.448657e+05
# std    6.720553e+07       2.417552       2.200800  9.322810e+04
# min    9.929264e+08       0.000000       0.000000  0.000000e+00
# 25%    1.050803e+09       0.000000       0.000000  7.708925e+04
# 50%    1.108627e+09       0.000000       0.000000  1.384100e+05
# 75%    1.166813e+09       1.000000       0.000000  1.999738e+05
# max    1.224743e+09     162.000000     124.000000  1.500000e+06
#
#            days_live      photo_cnt          n_asq       bouwjaar  \
# count  183062.000000  183062.000000  183062.000000  183062.000000
# mean       27.645623      15.560794       0.990522    2007.173160
# std        20.929081       6.429427       2.706513       5.437412
# min         0.000000       0.000000       0.000000    1991.000000
# ...

# %%
df.drop(['src_ad_id'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    telclicks  bids  kleur            carrosserie   kmstand  days_live  \
# 0        0.0   0.0    Wit           Terreinwagen   90800.0        100
# 1        0.0  20.0  Zwart                      ?  335000.0         14
# 2        0.0   6.0    Wit  Hatchback (3/5-deurs)   53619.0         27
# 3        0.0  14.0  Zwart  Hatchback (3/5-deurs)  175000.0          3
# 4        0.0  12.0  Blauw  Hatchback (3/5-deurs)  150000.0          3
#
#    photo_cnt aantaldeuren  n_asq  bouwjaar     ...      energielabel  \
# 0          8            5    282    2011.0     ...                 B
# 1          8         None    147    2011.0     ...                 A
# 2         14            3    130    2009.0     ...                 A
# 3         11            3    125    2001.0     ...                 C
# 4          5            5    114    2007.0     ...                 B
#
#         brand   l2 ad_start_dt vermogen  webclicks  model aantalstoelen  \
# ...

# %%
df.corr()
# Out:
#            telclicks      bids   kmstand  days_live  photo_cnt     n_asq  \
# telclicks   1.000000  0.380256  0.197566   0.021673  -0.199770  0.508622
# bids        0.380256  1.000000  0.137114   0.164089  -0.194405  0.441852
# kmstand     0.197566  0.137114  1.000000   0.007226  -0.294691  0.163689
# days_live   0.021673  0.164089  0.007226   1.000000  -0.034307  0.041815
# photo_cnt  -0.199770 -0.194405 -0.294691  -0.034307   1.000000 -0.194408
# n_asq       0.508622  0.441852  0.163689   0.041815  -0.194408  1.000000
# bouwjaar   -0.238774 -0.199913 -0.605435  -0.000799   0.415896 -0.213097
# vermogen   -0.046441 -0.038515  0.110076   0.050028   0.207522 -0.031449
# webclicks   0.227526  0.026219  0.069621  -0.059654  -0.024720  0.152519
# price      -0.016609 -0.009206 -0.054252   0.003031   0.051204 -0.017947
#
#            bouwjaar  vermogen  webclicks     price
# telclicks -0.238774 -0.046441   0.227526 -0.016609
# bids      -0.199913 -0.038515   0.026219 -0.009206
# ...

# %%
df["price"].plot.box()

# %%
df["aantalstoelen"].value_counts()
# Out:
# 5                           124171
# 4                            25431
# None                         11726
# 2                             8128
# 7                             5899
# 3                             5326
# 6                             1620
# 9                              400
# 8                              289
# 1                               43
# 17                               3
# 20                               2
# 10                               2
# 50                               2
# UNIEKE AUTO!                     1
# 116 km NAP                       1
# 45                               1
# Automaat                         1
# 16                               1
# 140pk                            1
# AIRCO                            1
# 6 Cooper S Chili                 1
# Cruise                           1
# 3 dtj   75pk basic marge         1
# 9dti L2H1  100pk                 1
# 3500 KG Trekgewicht              1
# Leer                             1
# ...
